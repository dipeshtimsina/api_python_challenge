# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "../output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# pip install citipy

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 619

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"

units = "imperial"
cities_clean = []
counter = 0
set_counter = 1
# loop throught the list of units and append them to temperatures list
for city in cities:
    query_url = f"{url}appid={weather_api_key}&q={city}&units={units}"
    # Build query URL based on current element in units
    try:

        # Get weather data
        weather_response = requests.get(query_url)
        weather_json = weather_response.json()

        # Get temperature from JSON response
        temperature = weather_json["main"]["temp"]
        humidity = weather_json['main']['humidity']
        speed = weather_json['wind']['speed']
        cloud = weather_json['clouds']['all']
        lat = weather_json['coord']['lat']
        lng= weather_json['coord']['lon']
        country = weather_json['sys']['country']
        date.append(weather_json['dt'])
        print(f"counter {counter} city {city}")
        time.sleep(.2)
        counter += 1
        if counter == 55:
            counter = 0
            set_counter += 1
        cities_clean.append(city)
    except:
        print('City not Found')
# Out:
# counter 1 city albany
# counter 2 city ushuaia
# counter 3 city vostok
# counter 4 city cabo san lucas
# counter 5 city carbonia
# City not Found
# counter 7 city punta arenas
# counter 8 city kenai
# counter 9 city rongcheng
# counter 10 city maykor
# counter 11 city nyurba
# City not Found
# counter 13 city grand gaube
# counter 14 city sambava
# counter 15 city tautira
# counter 16 city atuona
# counter 17 city sitia
# counter 18 city mehamn
# counter 19 city castro
# counter 20 city lebu
# counter 21 city muros
# counter 22 city busselton
# counter 23 city nanortalik
# counter 24 city mar del plata
# counter 25 city aktash
# counter 26 city bluff
# counter 27 city qaanaaq
# City not Found
# City not Found
# counter 30 city faya
# counter 31 city saskylakh
# counter 32 city ouadda
# City not Found
# counter 34 city yerbogachen
# counter 35 city tiksi
# counter 36 city puerto ayora
# counter 37 city cherskiy
# counter 38 city mataura
# City not Found
# counter 40 city marathon
# City not Found
# counter 42 city port alfred
# counter 43 city rikitea
# City not Found
# counter 45 city new milford
# counter 46 city kanye
# counter 47 city uyuni
# counter 48 city dikson
# counter 49 city provideniya
# counter 50 city usinsk
# counter 51 city lavrentiya
# counter 52 city norman wells
# counter 53 city aripuana
# City not Found
# counter 55 city georgetown
# counter 56 city guymon
# counter 57 city mantua
# counter 58 city kavieng
# counter 59 city moindou
# counter 60 city belmonte
# counter 61 city eureka
# counter 62 city saint-philippe
# counter 63 city safaga
# counter 64 city tigpalay
# counter 65 city sorland
# counter 66 city coquimbo
# counter 67 city hami
# City not Found
# counter 69 city butaritari
# counter 70 city hermanus
# counter 71 city bredasdorp
# counter 72 city jamestown
# counter 73 city haifa
# counter 74 city camana
# counter 75 city colomi
# counter 76 city sain alto
# counter 77 city kununurra
# counter 78 city bonavista
# counter 79 city miravci
# counter 80 city thompson
# counter 81 city barrow
# counter 82 city alofi
# counter 83 city vila franca do campo
# counter 84 city gornopravdinsk
# counter 85 city nemuro
# City not Found
# counter 87 city ilulissat
# counter 88 city codrington
# counter 89 city irbit
# counter 90 city lagoa
# counter 91 city kutahya
# counter 92 city churapcha
# counter 93 city esperance
# counter 94 city hithadhoo
# counter 95 city arona
# counter 96 city umm kaddadah
# counter 97 city huntington
# counter 98 city saint-pierre
# counter 99 city birao
# counter 100 city hollister
# counter 101 city bria
# counter 102 city oktyabrskoye
# counter 103 city whitehorse
# counter 104 city omsukchan
# counter 516 city neiafu
# counter 517 city dhidhdhoo
# counter 518 city tazovskiy
# counter 519 city nishihara
# counter 520 city zhuhai
# City not Found
# counter 522 city marataizes
# counter 523 city oparino
# counter 524 city faanui
# counter 525 city manaus
# counter 526 city kupang
# counter 527 city ixtapa
# counter 528 city fortuna
# counter 529 city chaihe
# City not Found
# counter 531 city hwange
# counter 532 city southampton
# counter 533 city constitucion
# counter 534 city celestun
# counter 535 city manavalakurichi
# counter 536 city malvern
# counter 537 city kushiro
# counter 538 city qaqortoq
# counter 539 city armizonskoye
# counter 540 city olonets
# counter 541 city zyryanka
# counter 542 city juba
# counter 543 city yatou
# counter 544 city beloha
# counter 545 city tessalit
# counter 546 city daru
# counter 547 city hirado
# counter 548 city sarmanovo
# counter 549 city emporia
# counter 550 city warin chamrap
# counter 551 city otane
# counter 552 city ust-tsilma
# counter 553 city kuji
# counter 554 city mancio lima
# counter 555 city am timan
# counter 556 city yumen
# counter 557 city santander jimenez
# counter 558 city husavik
# counter 559 city kayerkan
# counter 560 city assiniboia
# counter 561 city luderitz
# City not Found
# counter 563 city jaciara
# City not Found
# counter 565 city charters towers
# counter 566 city ust-maya
# counter 567 city bukavu
# counter 568 city ciudad del maiz
# counter 569 city mirassol
# counter 570 city crotone
# City not Found
# counter 572 city gambela
# counter 573 city sao felix do xingu
# counter 574 city ryazanskaya
# counter 575 city verkhnyaya inta
# counter 576 city oktyabrskiy
# counter 577 city abapo
# counter 578 city la romana
# counter 579 city mildura
# counter 580 city sapulpa
# counter 581 city sept-iles
# counter 582 city russell
# counter 583 city batagay-alyta
# counter 584 city konosha
# City not Found
# counter 586 city srednekolymsk
# counter 587 city ust-tarka
# counter 588 city halifax
# counter 589 city tairua
# counter 590 city asau
# counter 591 city honningsvag
# counter 592 city acari
# counter 593 city moussoro
# counter 594 city inirida
# City not Found
# counter 596 city cayenne
# counter 597 city guaiuba
# counter 598 city mpulungu
# counter 599 city tonk
# counter 600 city samarai
# counter 601 city holalkere
# counter 602 city bouar
# counter 603 city havoysund
# City not Found
# counter 605 city glendive
# counter 606 city tukrah
# counter 607 city poum
# counter 608 city tommot
# counter 609 city surin
# counter 610 city teguldet
# counter 611 city igarka
# counter 612 city umm lajj
# counter 613 city kanniyakumari
# counter 614 city kargasok
# City not Found
# counter 616 city meybod
# counter 617 city el astillero
# counter 618 city kargil
# counter 619 city oriximina

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_dict = {
    "City": cities_clean,
    "Lat": lat,
    "Lng": lng,
    "Max Temp": max_temp,
    "Humidity": humidity,
    "Cloudiness": cloudiness,
    "Wind Speed": wind_speed,
    "Country": country,
    "Date": date
}
city_weather_df = pd.DataFrame(weather_dict)
city_weather_df.head()

# %%
city_weather_df.to_csv("../output_data/city_weather_df.csv", index_label='City ID')

# %% [markdown]
# #  Get the indices of cities that have humidity over 100%.
# <!-- city_df['humidity'].describe() -->

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
city_weather_df.plot.scatter("Lat", "Max Temp", marker="x", edgecolors="red")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Highest Temperature (F)")
plt.title("Latitue vs. City's Maximum Temperature")

# to save 
plt.savefig("lat_vs_temp.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
city_weather_df.plot.scatter("Lat", "Humidity", marker="x", edgecolors="red")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Percent Humidity")
plt.title("Latitue vs. City's Humidity Percentage")

# to save 
plt.savefig("lat_vs_humidity.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
city_weather_df.plot.scatter("Lat", "Cloudiness", marker="x", edgecolors="red")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title("Latitue vs. City's Cloudiness")

# to save 
plt.savefig("lat_vs_cloud.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
city_weather_df.plot.scatter("Lat", "Wind Speed", marker="x", edgecolors="red")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Wind Speed mph")
plt.title("Latitue vs. City's Wind Speed in Miles per Hour")

# to save 
plt.savefig("lat_vs_wind.png")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
n_hemisphere= city_weather_df[city_weather_df['Lat'] >= 0]
s_hemisphere= city_weather_df[city_weather_df['Lat'] < 0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = (n_hemisphere["Lat"])
y_values = (n_hemisphere["Max Temp"])

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values, "b-")
plt.annotate(line_eq,(10,0),fontsize=16,color="black")

print(f"The r-value is: {rvalue**2}")

plt.xlabel("Latitude")
plt.ylabel("Maximum Temperature (F)")
plt.title("Northern Hemisphere Latitude vs. Temperature")

plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = (s_hemisphere["Lat"])
y_values = (s_hemisphere["Max Temp"])

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values, "b-")
plt.annotate(line_eq,(10,0),fontsize=16,color="black")

print(f"The r-value is: {rvalue**2}")

plt.xlabel("Latitude")
plt.ylabel("Maximum Temperature (F)")
plt.title("Southern Hemisphere Latitude vs. Temperature")

plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = (n_hemisphere["Lat"])
y_values = (n_hemisphere["Humidity"])

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values, "b-")
plt.annotate(line_eq,(10,0),fontsize=16,color="black")

print(f"The r-value is: {rvalue**2}")

plt.xlabel("Latitude")
plt.ylabel("Humidity Percentage")
plt.title("Northern Hemisphere Latitude vs. Humidity")

plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = (s_hemisphere["Lat"])
y_values = (s_hemisphere["Humidity"])

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values, "b-")
plt.annotate(line_eq,(10,0),fontsize=16,color="black")

print(f"The r-value is: {rvalue**2}")

plt.xlabel("Latitude")
plt.ylabel("Humidity Percentage")
plt.title("Southern Hemisphere Latitude vs. Humidity")

plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = (n_hemisphere["Lat"])
y_values = (n_hemisphere["Cloudiness"])

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values, "b-")
plt.annotate(line_eq,(10,0),fontsize=16,color="black")

print(f"The r-value is: {rvalue**2}")

plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title("Northern Hemisphere Latitude vs. Cloudiness")

plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = (s_hemisphere["Lat"])
y_values = (s_hemisphere["Cloudiness"])

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values, "b-")
plt.annotate(line_eq,(10,0),fontsize=16,color="black")

print(f"The r-value is: {rvalue**2}")

plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title("Southern Hemisphere Latitude vs. Cloudiness")

plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = (n_hemisphere["Lat"])
y_values = (n_hemisphere["Wind Speed"])

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values, "b-")
plt.annotate(line_eq,(10,0),fontsize=16,color="black")

print(f"The r-value is: {rvalue**2}")

plt.xlabel("Latitude")
plt.ylabel("Wind Speed mph")
plt.title("Northern Hemisphere Latitude vs. Wind Speed")

plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = (s_hemisphere["Lat"])
y_values = (s_hemisphere["Wind Speed"])

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values, "b-")
plt.annotate(line_eq,(10,0),fontsize=16,color="black")

print(f"The r-value is: {rvalue**2}")

plt.xlabel("Latitude")
plt.ylabel("Wind Speed mph")
plt.title("Southern Hemisphere Latitude vs. Wind Speed")

plt.show()

# %%
# MY API KEYS GOT RESTRICTED but I have used the data for both weather and vacation from the time
# I was able to access and create a csv file with random cites
